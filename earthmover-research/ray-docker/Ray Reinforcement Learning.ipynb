# %%
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.connectors.env_to_module import FlattenObservations

# %%
# 1. Configure the algorithm,
config = (
    PPOConfig()
    .environment("Taxi-v3")
    .env_runners(
        num_env_runners=2,
        # Observations are discrete (ints) -> We need to flatten (one-hot) them.
        env_to_module_connector=lambda env: FlattenObservations(),
    )
    .evaluation(evaluation_num_env_runners=1)
)

# %%
# 2. build the algorithm ..
algo = config.build()
# Out:
# 2025-01-10 11:49:10,190	WARNING algorithm_config.py:4355 -- You have specified 1 evaluation workers, but your `evaluation_interval` is 0 or None! Therefore, evaluation doesn't occur automatically with each call to `Algorithm.train()`. Instead, you have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# 2025-01-10 11:49:10,212	WARNING ppo.py:295 -- You are running PPO on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False,enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# /home/ray/anaconda3/lib/python3.9/site-packages/ray/rllib/algorithms/algorithm.py:569: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2025-01-10 11:49:10,294	INFO worker.py:1636 -- Connecting to existing Ray cluster at address: 172.17.0.2:6379...
# 2025-01-10 11:49:10,320	INFO worker.py:1812 -- Connected to Ray cluster. View the dashboard at 172.17.0.2:8265
# (SingleAgentEnvRunner pid=618) 2025-01-10 11:49:16,111	WARNING deprecation.py:50 -- DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# 2025-01-10 11:49:16,494	WARNING deprecation.py:50 -- DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# 2025-01-10 11:49:16,540	WARNING algorithm_config.py:4355 -- You have specified 1 evaluation workers, but your `evaluation_interval` is 0 or None! Therefore, evaluation doesn't occur automatically with each call to `Algorithm.train()`. Instead, you have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# 2025-01-10 11:49:16,542	WARNING ppo.py:295 -- You are running PPO on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False,enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# /home/ray/anaconda3/lib/python3.9/site-packages/gymnasium/envs/registration.py:642: UserWarning: WARN: Overriding environment rllib-single-agent-env-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# 2025-01-10 11:49:21,113	WARNING rl_module.py:427 -- Could not create a Catalog object for your RLModule! If you are not using the new API stack yet, make sure to switch it off in your config: `config.api_stack(enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False)`. Some algos already use the new stack by default. Ignore this message, if your RLModule does not use a Catalog to build its sub-components.
# 2025-01-10 11:49:23,539	INFO trainable.py:161 -- Trainable.setup took 13.254 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2025-01-10 11:49:23,543	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
# 3. .. train it ..
for _ in range(5):
    print(algo.train())
# Out:
# {'timers': {'training_iteration': 41.90190400900002, 'restore_workers': 5.786700000953715e-05, 'training_step': 41.90137965699995, 'env_runner_sampling_timer': 4.418147753000028, 'learner_update_timer': 37.46149608600001, 'synch_weights': 0.013557637999952021}, 'env_runners': {'num_agent_steps_sampled': {'default_agent': 4000}, 'episode_len_max': 200, 'num_env_steps_sampled_lifetime': 4000, 'weights_seq_no': 0.0, 'episode_len_mean': 200.0, 'num_agent_steps_sampled_lifetime': {'default_agent': 4000}, 'episode_return_max': -650.0, 'agent_episode_returns_mean': {'default_agent': -787.25}, 'sample': 4.31811074700002, 'episode_return_min': -983.0, 'episode_len_min': 200, 'num_env_steps_sampled': 4000, 'module_episode_returns_mean': {'default_policy': -787.25}, 'episode_return_mean': -787.25, 'num_module_steps_sampled_lifetime': {'default_policy': 4000}, 'num_module_steps_sampled': {'default_policy': 4000}, 'episode_duration_sec_mean': 0.4242936973500008, 'num_episodes_lifetime': 20, 'num_episodes': 20}, 'learners': {'default_policy': {'mean_kl_loss': 0.01851804181933403, 'total_loss': 9.887557983398438, 'num_module_steps_trained': 4020, 'entropy': 1.7744098901748657, 'curr_entropy_coeff': 0.0, 'num_trainable_parameters': 389895, 'vf_loss': 9.924951553344727, 'vf_loss_unclipped': 58247.6640625, 'num_module_steps_trained_lifetime': 4020, 'vf_explained_var': 8.487701416015625e-05, 'default_optimizer_learning_rate': 5e-05, 'module_train_batch_size_mean': 4020, 'policy_loss': -0.04109721630811691, 'diff_num_grad_updates_vs_sampler_policy': 0.0, 'gradients_default_optimizer_global_norm': 0.3246590495109558, 'curr_kl_coeff': 0.20000000298023224, 'weights_seq_no': 1.0, 'num_non_trainable_parameters': 0}, '__all_modules__': {'num_env_steps_trained_lifetime': 4020, 'num_non_trainable_parameters': 0, 'num_env_steps_trained': 4020, 'learner_connector_timer': 0.4373467499999606, 'num_module_steps_trained': 4020, 'num_trainable_parameters': 389895, 'num_module_steps_trained_lifetime': 4020}}, 'num_training_step_calls_per_iteration': 1, 'num_env_steps_sampled_lifetime': 4000, 'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0}, 'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0}, 'done': False, 'training_iteration': 1, 'trial_id': 'default', 'date': '2025-01-10_11-50-07', 'timestamp': 1736538607, 'time_this_iter_s': 41.937812089920044, 'time_total_s': 41.937812089920044, 'pid': 521, 'hostname': 'd91e16ee7279', 'node_ip': '172.17.0.2', 'config': {'exploration_config': {}, 'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ddp_kwargs': {}, 'torch_skip_nan_gradients': False, 'env': 'Taxi-v3', 'env_config': {}, 'observation_space': None, 'action_space': None, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, '_is_atari': None, 'disable_env_checking': False, 'env_task_fn': None, 'render_env': False, 'action_mask_key': 'action_mask', 'env_runner_cls': None, 'num_env_runners': 2, 'num_envs_per_env_runner': 1, 'num_cpus_per_env_runner': 1, 'num_gpus_per_env_runner': 0, 'custom_resources_per_env_runner': {}, 'validate_env_runners_after_construction': True, 'm ...
# {'timers': {'training_iteration': 41.88544577911002, 'restore_workers': 5.744973000901155e-05, 'training_step': 41.88492108552995, 'env_runner_sampling_timer': 4.414430703240028, 'learner_update_timer': 37.44880002916001, 'synch_weights': 0.013561332809952092, 'synch_env_connectors': 0.02268187879000834}, 'env_runners': {'num_agent_steps_sampled': {'default_agent': 4000}, 'episode_len_max': 200, 'num_env_steps_sampled_lifetime': 8000, 'weights_seq_no': 1.0, 'episode_len_mean': 198.8, 'num_agent_steps_sampled_lifetime': {'default_agent': 8000}, 'episode_return_max': -395.0, 'agent_episode_returns_mean': {'default_agent': -735.6}, 'sample': 4.318043958017745, 'episode_return_min': -983.0, 'episode_len_min': 128, 'num_env_steps_sampled': 4000, 'module_episode_returns_mean': {'default_policy': -735.6}, 'episode_return_mean': -735.6, 'num_module_steps_sampled_lifetime': {'default_policy': 8000}, 'num_module_steps_sampled': {'default_policy': 4000}, 'episode_duration_sec_mean': 0.41134458941666024, 'num_episodes_lifetime': 40, 'num_episodes': 20, 'time_between_sampling': 37.6523648875}, 'learners': {'default_policy': {'mean_kl_loss': 0.020253797993063927, 'total_loss': 9.945630073547363, 'num_module_steps_trained': 4021, 'entropy': 1.7401176691055298, 'curr_entropy_coeff': 0.0, 'num_trainable_parameters': 389895.0, 'vf_loss': 9.928584098815918, 'vf_loss_unclipped': 37994.1484375, 'num_module_steps_trained_lifetime': 8041, 'vf_explained_var': 0.0016324520111083984, 'default_optimizer_learning_rate': 5e-05, 'module_train_batch_size_mean': 4020.0001, 'policy_loss': 0.012994961813092232, 'diff_num_grad_updates_vs_sampler_policy': 0.0, 'gradients_default_optimizer_global_norm': 0.2320830076932907, 'curr_kl_coeff': 0.30000001192092896, 'weights_seq_no': 2.0, 'num_non_trainable_parameters': 0.0}, '__all_modules__': {'num_env_steps_trained_lifetime': 8041, 'num_non_trainable_parameters': 0.0, 'num_env_steps_trained': 4021, 'learner_connector_timer': 0.4373375249323606, 'num_module_steps_trained': 4021, 'num_trainable_parameters': 389895.0, 'num_module_steps_trained_lifetime': 8041}}, 'num_training_step_calls_per_iteration': 1, 'num_env_steps_sampled_lifetime': 8000, 'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0}, 'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0}, 'done': False, 'training_iteration': 2, 'trial_id': 'default', 'date': '2025-01-10_11-50-47', 'timestamp': 1736538647, 'time_this_iter_s': 40.28171706199646, 'time_total_s': 82.2195291519165, 'pid': 521, 'hostname': 'd91e16ee7279', 'node_ip': '172.17.0.2', 'config': {'exploration_config': {}, 'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ddp_kwargs': {}, 'torch_skip_nan_gradients': False, 'env': 'Taxi-v3', 'env_config': {}, 'observation_space': None, 'action_space': None, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, '_is_atari': None, 'disable_env_checking': False, 'env_task_fn': None, 'render_env': False, 'action_mask_key': 'action_mask', 'env_runner_cls': None, 'num_env_runners': 2, 'num_envs_per_env_runner': 1, 'num_cpus_per_env_runner': 1, 'num_gpus_per_env_runner' ...
# {'timers': {'training_iteration': 42.091465833298926, 'restore_workers': 5.704306270870348e-05, 'training_step': 42.090941579224655, 'env_runner_sampling_timer': 4.405723554357627, 'learner_update_timer': 37.663350197588414, 'synch_weights': 0.013763969131852651, 'synch_env_connectors': 0.022583709932108193}, 'env_runners': {'num_agent_steps_sampled': {'default_agent': 4000}, 'episode_len_max': 200, 'num_env_steps_sampled_lifetime': 12000, 'weights_seq_no': 2.0, 'episode_len_mean': 198.56, 'num_agent_steps_sampled_lifetime': {'default_agent': 12000}, 'episode_return_max': -395.0, 'agent_episode_returns_mean': {'default_agent': -685.4}, 'sample': 4.317814547395243, 'episode_return_min': -983.0, 'episode_len_min': 128, 'num_env_steps_sampled': 4000, 'module_episode_returns_mean': {'default_policy': -685.4}, 'episode_return_mean': -685.4, 'num_module_steps_sampled_lifetime': {'default_policy': 12000}, 'num_module_steps_sampled': {'default_policy': 4000}, 'episode_duration_sec_mean': 0.393053128549991, 'num_episodes_lifetime': 60, 'num_episodes': 20, 'time_between_sampling': 37.65209936190168}, 'learners': {'default_policy': {'mean_kl_loss': 0.02425193414092064, 'total_loss': 9.94729995727539, 'num_module_steps_trained': 4021, 'entropy': 1.7069947719573975, 'curr_entropy_coeff': 0.0, 'num_trainable_parameters': 389895.0, 'vf_loss': 9.922792434692383, 'vf_loss_unclipped': 34876.4453125, 'num_module_steps_trained_lifetime': 12062, 'vf_explained_var': 0.0021553635597229004, 'default_optimizer_learning_rate': 5e-05, 'module_train_batch_size_mean': 4020.000298, 'policy_loss': 0.017231442034244537, 'diff_num_grad_updates_vs_sampler_policy': 0.0, 'gradients_default_optimizer_global_norm': 0.4360618591308594, 'curr_kl_coeff': 0.45000001788139343, 'weights_seq_no': 3.0, 'num_non_trainable_parameters': 0.0}, '__all_modules__': {'num_env_steps_trained_lifetime': 12062, 'num_non_trainable_parameters': 0.0, 'num_env_steps_trained': 4021, 'learner_connector_timer': 0.4373019046748126, 'num_module_steps_trained': 4021, 'num_trainable_parameters': 389895.0, 'num_module_steps_trained_lifetime': 12062}}, 'num_training_step_calls_per_iteration': 1, 'num_env_steps_sampled_lifetime': 12000, 'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0}, 'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0}, 'done': False, 'training_iteration': 3, 'trial_id': 'default', 'date': '2025-01-10_11-51-50', 'timestamp': 1736538710, 'time_this_iter_s': 62.50452780723572, 'time_total_s': 144.72405695915222, 'pid': 521, 'hostname': 'd91e16ee7279', 'node_ip': '172.17.0.2', 'config': {'exploration_config': {}, 'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ddp_kwargs': {}, 'torch_skip_nan_gradients': False, 'env': 'Taxi-v3', 'env_config': {}, 'observation_space': None, 'action_space': None, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, '_is_atari': None, 'disable_env_checking': False, 'env_task_fn': None, 'render_env': False, 'action_mask_key': 'action_mask', 'env_runner_cls': None, 'num_env_runners': 2, 'num_envs_per_env_runner': 1, 'num_cpus_per_env_runner': 1, 'num_gpus ...
# {'timers': {'training_iteration': 42.142346527885934, 'restore_workers': 5.668986208193315e-05, 'training_step': 42.14182334864241, 'env_runner_sampling_timer': 4.404346153734051, 'learner_update_timer': 37.71563575924253, 'synch_weights': 0.013768398460533678, 'synch_env_connectors': 0.02263937171278741}, 'env_runners': {'num_agent_steps_sampled': {'default_agent': 4000}, 'episode_len_max': 200, 'num_env_steps_sampled_lifetime': 16000, 'weights_seq_no': 3.0, 'episode_len_mean': 198.26, 'num_agent_steps_sampled_lifetime': {'default_agent': 16000}, 'episode_return_max': -302.0, 'agent_episode_returns_mean': {'default_agent': -629.78}, 'sample': 4.3175682951162235, 'episode_return_min': -983.0, 'episode_len_min': 125, 'num_env_steps_sampled': 4000, 'module_episode_returns_mean': {'default_policy': -629.78}, 'episode_return_mean': -629.78, 'num_module_steps_sampled_lifetime': {'default_policy': 16000}, 'num_module_steps_sampled': {'default_policy': 4000}, 'episode_duration_sec_mean': 0.3800229982399941, 'num_episodes_lifetime': 80, 'num_episodes': 20, 'time_between_sampling': 37.6560973932766}, 'learners': {'default_policy': {'mean_kl_loss': 0.022286489605903625, 'total_loss': 9.891494750976562, 'num_module_steps_trained': 4022, 'entropy': 1.6741291284561157, 'curr_entropy_coeff': 0.0, 'num_trainable_parameters': 389895.0, 'vf_loss': 9.923526763916016, 'vf_loss_unclipped': 29998.041015625, 'num_module_steps_trained_lifetime': 16084, 'vf_explained_var': 0.0015966296195983887, 'default_optimizer_learning_rate': 5e-05, 'module_train_batch_size_mean': 4020.0006920299998, 'policy_loss': -0.04206154868006706, 'diff_num_grad_updates_vs_sampler_policy': 0.0, 'gradients_default_optimizer_global_norm': 0.4817207455635071, 'curr_kl_coeff': 0.675000011920929, 'weights_seq_no': 4.0, 'num_non_trainable_parameters': 0.0}, '__all_modules__': {'num_env_steps_trained_lifetime': 16084, 'num_non_trainable_parameters': 0.0, 'num_env_steps_trained': 4022, 'learner_connector_timer': 0.4372412238190223, 'num_module_steps_trained': 4022, 'num_trainable_parameters': 389895.0, 'num_module_steps_trained_lifetime': 16084}}, 'num_training_step_calls_per_iteration': 1, 'num_env_steps_sampled_lifetime': 16000, 'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0}, 'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0}, 'done': False, 'training_iteration': 4, 'trial_id': 'default', 'date': '2025-01-10_11-52-37', 'timestamp': 1736538757, 'time_this_iter_s': 47.2129762172699, 'time_total_s': 191.93703317642212, 'pid': 521, 'hostname': 'd91e16ee7279', 'node_ip': '172.17.0.2', 'config': {'exploration_config': {}, 'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ddp_kwargs': {}, 'torch_skip_nan_gradients': False, 'env': 'Taxi-v3', 'env_config': {}, 'observation_space': None, 'action_space': None, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, '_is_atari': None, 'disable_env_checking': False, 'env_task_fn': None, 'render_env': False, 'action_mask_key': 'action_mask', 'env_runner_cls': None, 'num_env_runners': 2, 'num_envs_per_env_runner': 1, 'num_cpus_per_env_runner': 1,  ...
# {'timers': {'training_iteration': 42.108295450547075, 'restore_workers': 5.632364346137567e-05, 'training_step': 42.10777345327598, 'env_runner_sampling_timer': 4.395861607546711, 'learner_update_timer': 37.690129377210106, 'synch_weights': 0.013765467295928927, 'synch_env_connectors': 0.0226609642556596}, 'env_runners': {'num_agent_steps_sampled': {'default_agent': 4000}, 'episode_len_max': 200, 'num_env_steps_sampled_lifetime': 20000, 'weights_seq_no': 4.0, 'episode_len_mean': 198.26, 'num_agent_steps_sampled_lifetime': {'default_agent': 20000}, 'episode_return_max': -302.0, 'agent_episode_returns_mean': {'default_agent': -632.66}, 'sample': 4.317164989425107, 'episode_return_min': -983.0, 'episode_len_min': 125, 'num_env_steps_sampled': 4000, 'module_episode_returns_mean': {'default_policy': -632.66}, 'episode_return_mean': -632.66, 'num_module_steps_sampled_lifetime': {'default_policy': 20000}, 'num_module_steps_sampled': {'default_policy': 4000}, 'episode_duration_sec_mean': 0.3809422152999917, 'num_episodes_lifetime': 100, 'num_episodes': 20, 'time_between_sampling': 37.661046883830494}, 'learners': {'default_policy': {'mean_kl_loss': 0.01979990303516388, 'total_loss': 9.770617485046387, 'num_module_steps_trained': 4022, 'entropy': 1.6489866971969604, 'curr_entropy_coeff': 0.0, 'num_trainable_parameters': 389895.0, 'vf_loss': 9.84964370727539, 'vf_loss_unclipped': 32047.005859375, 'num_module_steps_trained_lifetime': 20106, 'vf_explained_var': 0.0014771223068237305, 'default_optimizer_learning_rate': 5e-05, 'module_train_batch_size_mean': 4020.0012781496, 'policy_loss': -0.09239179641008377, 'diff_num_grad_updates_vs_sampler_policy': 0.0, 'gradients_default_optimizer_global_norm': 0.5593472719192505, 'curr_kl_coeff': 0.675000011920929, 'weights_seq_no': 5.0, 'num_non_trainable_parameters': 0.0}, '__all_modules__': {'num_env_steps_trained_lifetime': 20106, 'num_non_trainable_parameters': 0.0, 'num_env_steps_trained': 4022, 'learner_connector_timer': 0.4371880541357803, 'num_module_steps_trained': 4022, 'num_trainable_parameters': 389895.0, 'num_module_steps_trained_lifetime': 20106}}, 'num_training_step_calls_per_iteration': 1, 'num_env_steps_sampled_lifetime': 20000, 'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0}, 'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 0}, 'done': False, 'training_iteration': 5, 'trial_id': 'default', 'date': '2025-01-10_11-53-16', 'timestamp': 1736538796, 'time_this_iter_s': 38.76674270629883, 'time_total_s': 230.70377588272095, 'pid': 521, 'hostname': 'd91e16ee7279', 'node_ip': '172.17.0.2', 'config': {'exploration_config': {}, 'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ddp_kwargs': {}, 'torch_skip_nan_gradients': False, 'env': 'Taxi-v3', 'env_config': {}, 'observation_space': None, 'action_space': None, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, '_is_atari': None, 'disable_env_checking': False, 'env_task_fn': None, 'render_env': False, 'action_mask_key': 'action_mask', 'env_runner_cls': None, 'num_env_runners': 2, 'num_envs_per_env_runner': 1, 'num_cpus_per_env_runner': 1, 'n ...

# %%
# 4. .. and evaluate it.
algo.evaluate()
# Out:
# {'env_runners': {'num_agent_steps_sampled': {'default_agent': 2000},
#   'episode_len_max': 200,
#   'num_env_steps_sampled_lifetime': 2000,
#   'weights_seq_no': 5.0,
#   'episode_len_mean': 200.0,
#   'num_agent_steps_sampled_lifetime': {'default_agent': 2000},
#   'episode_return_max': -452.0,
#   'agent_episode_returns_mean': {'default_agent': -562.7},
#   'sample': 3.2004002639999953,
#   'episode_return_min': -686.0,
#   'episode_len_min': 200,
#   'num_env_steps_sampled': 2000,
#   'module_episode_returns_mean': {'default_policy': -562.7},
#   'episode_return_mean': -562.7,
#   'num_module_steps_sampled_lifetime': {'default_policy': 2000},
#   'num_module_steps_sampled': {'default_policy': 2000},
#   'episode_duration_sec_mean': 0.3155440947999978,
#   'num_episodes_lifetime': 10,
#   'num_episodes': 10}}
